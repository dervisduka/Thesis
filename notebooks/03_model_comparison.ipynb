# %% [markdown]
# # Final Model Comparison\n\nRun both pipelines and inspect the combined output CSV.

# %%
import pandas as pd\nfrom src.pipeline import run_full_comparison\n\n# Update paths if needed\nrun_full_comparison('data/creditcard.csv', 'data/phishing.csv')\npd.read_csv('outputs/results/final_model_comparison.csv').head()
