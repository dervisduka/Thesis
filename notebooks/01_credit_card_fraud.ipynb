# %% [markdown]
# # Credit Card Fraud Detection\n\nThis notebook is a starter for fraud dataset EDA/training.

# %%
from src.pipeline import run_dataset_pipeline\n\n# Update path if needed\nrun_dataset_pipeline(dataset_kind='fraud', input_csv='data/creditcard.csv')
