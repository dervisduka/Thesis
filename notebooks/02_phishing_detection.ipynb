# %% [markdown]
# # Phishing Website Detection\n\nThis notebook is a starter for phishing dataset EDA/training.

# %%
from src.pipeline import run_dataset_pipeline\n\n# Update path if needed\nrun_dataset_pipeline(dataset_kind='phishing', input_csv='data/phishing.csv')
